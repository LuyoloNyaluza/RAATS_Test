# %%
import subprocess
from langchain_community.llms import Ollama

def ollama_prompt(prompt):
             result = subprocess.run(
                 ["ollama", "run", "llama3", prompt],
                 capture_output=True, text=True, check=True
             )
             return result.stdout.strip()

llm = Ollama(model="llama3")
print("LangChain Ollama response:")
print(llm("What is the sentiment of the word 'bullish'?"))

print("\nDirect CLI Ollama response:")
print(ollama_prompt("Explain a moving average in one sentence."))
# Out:
# LangChain Ollama response:
# C:\Users\Zamuxolo\AppData\Local\Temp\ipykernel_33208\3712578772.py:13: LangChainDeprecationWarning: The method `BaseLLM.__call__` was deprecated in langchain-core 0.1.7 and will be removed in 1.0. Use invoke instead.
#   print(llm("What is the sentiment of the word 'bullish'?"))
# The word "bullish" has a positive sentiment. In the context of finance and economics, "bullish" refers to a market trend or outlook that is optimistic and expects an increase in prices or values. A bullish attitude is one that is confident and optimistic, expecting good things to happen.
#
# In general, the term "bullish" is associated with positivity, confidence, and enthusiasm. It implies a sense of hopefulness and anticipation for success or improvement.
#
# Direct CLI Ollama response:
