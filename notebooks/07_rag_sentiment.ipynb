# %%
# In[1]: Fix import path, then import both chains
import sys
import os

# Add project root to path so `src` is importable
project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))
if project_root not in sys.path:
    sys.path.insert(0, project_root)

# Force-reload the module in case an earlier cell run cached an older version
import importlib
if "src.rag.financial_sentiment_rag" in sys.modules:
    importlib.reload(sys.modules["src.rag.financial_sentiment_rag"])

from src.rag.financial_sentiment_rag import (
    create_financial_rag_chain,
    create_sentiment_chain,
    extract_stock_name,
)
from langchain_ollama import OllamaLLM

vectorstore_path = os.path.join(project_root, "data", "vector_stores", "faiss_news")

qa_chain = create_financial_rag_chain(vectorstore_path=vectorstore_path)
sentiment_fn = create_sentiment_chain(vectorstore_path=vectorstore_path)
extractor_llm = OllamaLLM(model="llama3")

# In[2]: Test with sample questions
test_questions = [
    "What is the sentiment for Apple based on recent news?",
    "How is Microsoft performing according to latest financial headlines?",
    "What does the news suggest about Tesla's market position?",
    "Is the sentiment for Google positive or negative in recent articles?",
    "What is the overall outlook for Amazon based on current news?"
]

print("Financial Sentiment Analysis Results:")
print("=" * 50)
for question in test_questions:
    stock = extract_stock_name(question, llm=extractor_llm)
    answer = sentiment_fn(stock)

    print(f"\nQ: {question}")
    print(f"(extracted stock: {stock})")
    print(f"A: {answer.strip()}")
# Out:
# Financial Sentiment Analysis Results:
# ==================================================
#
# Q: What is the sentiment for Apple based on recent news?
# (extracted stock: Apple)
# A: Based on the provided news headlines and summaries, the overall sentiment for Apple is predominantly POSITIVE.
#
# Positive indicators:
#
# * Apple shares rise after new iPhone launch: This suggests that investors are reacting positively to the new product, indicating confidence in the company's future performance.
#
# No negative indicators are explicitly mentioned in the provided news headlines and summaries. The mention of Google's AI breakthrough and technology stocks gaining may indicate a positive trend in the broader tech industry, which could also benefit Apple.
#
# The weakening of the Indian rupee against the US dollar is a macroeconomic indicator that is not directly related to Apple's sentiment.
#
# Therefore, considering both positive and negative indicators, the overall sentiment for Apple is predominantly POSITIVE.
#
# Q: How is Microsoft performing according to latest financial headlines?
# (extracted stock: Microsoft)
# A: Based on the provided news headlines and summaries, I would conclude that the overall sentiment for Microsoft is NEUTRAL.
#
# There are no specific news articles or mentions of Microsoft in the provided summaries. The news focuses on technology stocks, AI breakthroughs, and global market trends, which do not directly impact Microsoft's sentiment. The overall tone of the news is neutral, with no notable positive or negative indicators for Microsoft.
#
# In the absence of any specific news or indicators related to Microsoft, I would not attribute a sentiment of positive, negative, or neutral based on the provided news. The neutrality of the news suggests that Microsoft's sentiment is likely unaffected by the current market trends and news.
#
# Q: What does the news suggest about Tesla's market position?
# (extracted stock: Tesla)
# A: Based on the provided news headlines and summaries, there are no specific news articles or mentions about Tesla. The headlines and summaries focus on general market trends, technology stocks, and announcements from other companies like Google and Apple. As a result, there are no positive or negative indicators related to Tesla.
#
# Given the absence of any Tesla-related news, the overall sentiment for Tesla is NEUTRAL.
#
# Q: Is the sentiment for Google positive or negative in recent articles?
# (extracted stock: Google)
# A: Based on the news headlines and summaries, the overall sentiment for Google is predominantly POSITIVE.
#
# Positive indicators:
#
# * Google announces a new AI breakthrough, which suggests that the company is innovating and pushing the boundaries in the field of artificial intelligence.
# * Technology stocks, which include Google, gain as investors continue to assess the outlook for artificial intelligence investment, implying that Google's AI breakthrough is likely to be well-received by the market.
#
# Negative indicators:
#
# * There are no specific negative news items mentioned about Google in the headlines or summaries.
#
# Neutral indicators:
#
# * The news articles do not provide any specific information about Google's financial performance, revenue, or market share, which could be considered neutral.
#
# Overall, the positive indicators outweigh the neutral ones, suggesting that the overall sentiment for Google is predominantly POSITIVE.
#
# Q: What is the overall outlook for Amazon based on current news?
# (extracted stock: Amazon)
# A: Based on the provided news headlines and summaries, there is no direct mention of Amazon. The news stories are about Google, Apple, and the Indian rupee, which are unrelated to Amazon. Therefore, it is not possible to determine the overall sentiment for Amazon based on these news articles.
#
# In the absence of any relevant news about Amazon, the sentiment for the company remains NEUTRAL.
